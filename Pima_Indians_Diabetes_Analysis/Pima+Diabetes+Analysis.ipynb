# %% [markdown]
# # Foundations of Data Science Project - Diabetes Analysis
#
# ---------------
# ## Context
# ---------------
#
# Diabetes is one of the most frequent diseases worldwide and the number of diabetic patients are growing over the years. The main cause of diabetes remains unknown, yet scientists believe that both genetic factors and environmental lifestyle play a major role in diabetes.
#
# A few years ago research was done on a tribe in America which is called the Pima tribe. In this tribe, it was found that the ladies are prone to diabetes very early. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients were females at least 21 years old of Pima tribe.
#
# -----------------
# ## Objective
# -----------------
#
# Here, we are analyzing different aspects of Diabetes in the Pima Diabetes Analysis by doing Exploratory Data Analysis.
#
# -------------------------
# ## Data Dictionary
# -------------------------
#
# The dataset has the following information:
#
# * Pregnancies: Number of times pregnant
# * Glucose: Plasma glucose concentration over 2 hours in an oral glucose tolerance test
# * BloodPressure: Diastolic blood pressure (mm Hg)
# * SkinThickness: Triceps skin fold thickness (mm)
# * Insulin: 2-Hour serum insulin (mu U/ml)
# * BMI: Body mass index (weight in kg/(height in m)^2)
# * DiabetesPedigreeFunction: A function that scores the likelihood of diabetes based on family history.
# * Age: Age in years
# * Outcome: Class variable (0: a person is not diabetic or 1: a person is diabetic)

# %% [markdown]
# ## Q 1: Import the necessary libraries and briefly explain the use of each library (3 Marks)

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 1:
#   pandas library is used for data manipulation and analysis
#   numpy library is used for working with arrays
#   matplotlib.pyplot library is for visualization
#   seaborn library is for visualization

# %% [markdown]
# ## Q 2: Read the given dataset (1 Mark)

# %%
pima = pd.read_csv("diabetes.csv")

# %% [markdown]
# ## Q3. Show the last 10 records of the dataset. How many columns are there? (1 Mark)

# %%
pima.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76             20       79  37.5
# 759            6      190             92             20       79  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31       79  44.0
# 762            9       89             62             20       79  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27       79  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60             20       79  30.1
# 767            1       93             70             31       79  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 3:
#   9 columns

# %% [markdown]
# ## Q4. Show the first 10 records of the dataset (1 Mark)

# %%
pima.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0            6      148             72             35       79  33.600000
# 1            1       85             66             29       79  26.600000
# 2            8      183             64             20       79  23.300000
# 3            1       89             66             23       94  28.100000
# 4            0      137             40             35      168  43.100000
# 5            5      116             74             20       79  25.600000
# 6            3       78             50             32       88  31.000000
# 7           10      115             69             20       79  35.300000
# 8            2      197             70             45      543  30.500000
# 9            8      125             96             20       79  31.992578
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# ...

# %% [markdown]
# ## Q5. What do you understand by the dimension of the dataset? Find the dimension of the `pima` dataframe. (1 Mark)

# %%
pima.shape
# Out:
# (768, 9)

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 5:
#   What I understand is that the dimensions of the dataset are the columns and rows that are in the dataset.

# %% [markdown]
# ## Q6. What do you understand by the size of the dataset? Find the size of the `pima` dataframe. (1 Mark)

# %%
pima.size
# Out:
# 6912

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 6:
#   The amount of elements in the dataframe

# %% [markdown]
# ## Q7. What are the data types of all the variables in the data set? (2 Marks)
# **Hint: Use the info() function to get all the information about the dataset.**

# %%
pima.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 7:
#   The following is a table of all the data types for all the variables in the dataset:
#   variables                     data types
#   -----------------------------------------
#   Pregnancies                   int64
#   Glucose                       int64
#   BloodPressure                 int64
#   SkinThickness                 int64
#   Insulin                       int64
#   BMI                         float64
#   DiabetesPedigreeFunction    float64
#   Age                           int64
#   Outcome                       int64

# %% [markdown]
# ## Q8. What do we mean by missing values? Are there any missing values in the `pima` dataframe? (2 Marks)

# %%
pima.isnull().values.any()
# Out:
# False

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 8:
#   Missing values are empty or null elements in the dataset. There are no missing values in this dataframe.

# %% [markdown]
# ## Q9. What do the summary statistics of the data represent? Find the summary statistics for all variables except 'Outcome' in the `pima` data. Take one column/variable from the output table and explain all its statistical measures. (3 Marks)

# %%
pima.iloc[:,0:8].describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.675781      72.250000      26.447917  118.270833
# std       3.369578   30.436252      12.117203       9.733872   93.243829
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      20.000000   79.000000
# 50%       3.000000  117.000000      72.000000      23.000000   79.000000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  768.000000                768.000000  768.000000
# mean    32.450805                  0.471876   33.240885
# std      6.875374                  0.331329   11.760232
# min     18.200000                  0.078000   21.000000
# ...

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 9:
#   Summary statistics provide a brief overview of the distribution of a variable in a dataset.

# %% [markdown]
# ## Q 10. Plot the distribution plot for the variable 'BloodPressure'. Write detailed observations from the plot. (2 Marks)

# %%
sns.displot(pima['BloodPressure'], kind='kde')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 10:
#   The plot shows that BloodPressure values between approximately 60 and 80 are the most common, with a peak occurring at around 70. The plot also suggests that BloodPressure values below approximately 40 or above approximately 100 are less common in the population.

# %% [markdown]
# ## Q 11. What is the 'BMI' of the person having the highest 'Glucose'? (1 Mark)

# %%
pima[pima['Glucose']==pima['Glucose'].max()]['BMI']
# Out:
# 661    42.9
# Name: BMI, dtype: float64

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 11:
#   42.9

# %% [markdown]
# ## Q12.
# ### 12.1 What is the mean of the variable 'BMI'?
# ### 12.2 What is the median of the variable 'BMI'?
# ### 12.3 What is the mode of the variable 'BMI'?
# ### 12.4 Are the three measures of central tendency equal?
#
# ### (3 Marks)

# %%
m1 = pima['BMI'].mean()  # mean
print(m1)
m2 = pima['BMI'].median()  # median
print(m2)
m3 = pima['BMI'].mode()[0]  # mode
print(m3)
# Out:
# 32.45080515543619
# 32.0
# 32.0

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 12:
#   The mean is 32.45080515543619
#   The median is 32.0
#   The mode is 32.0
#   The three measure of central tendency are equal

# %% [markdown]
# ## Q13. How many women's 'Glucose' levels are above the mean level of 'Glucose'? (1 Mark)

# %%
pima[pima['Glucose']>pima['Glucose'].mean()].shape[0]
# Out:
# 343

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 13:
#   343

# %% [markdown]
# ## Q14. How many women have their 'BloodPressure' equal to the median of 'BloodPressure' and their 'BMI' less than the median of 'BMI'? (2 Marks)

# %%
pima[(pima['BloodPressure']==pima['BloodPressure'].median()) & (pima['BMI']<pima['BMI'].median())]
pima[(pima['BloodPressure']==pima['BloodPressure'].median()) & (pima['BMI']<pima['BMI'].median())].count()
# Out:
# Pregnancies                 22
# Glucose                     22
# BloodPressure               22
# SkinThickness               22
# Insulin                     22
# BMI                         22
# DiabetesPedigreeFunction    22
# Age                         22
# Outcome                     22
# dtype: int64

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 14:
#   22

# %% [markdown]
# ## Q15. Create a pairplot for the variables 'Glucose', 'SkinThickness', and 'DiabetesPedigreeFunction'. Write your observations from the plot. (4 Marks)

# %%
sns.pairplot(data=pima,vars=['Glucose', 'SkinThickness', 'DiabetesPedigreeFunction'], hue='Outcome')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 15:
#   The pairplots reveal that the distribution of Glucose levels is bimodal with most of the population having an outcome of 0 concentrated between 50 and 150 with a peak of 200 glucose, while for the population with an outcome of 1, it is skewed to the right between 100 and just under 200 glucose with a peak of 100 glucose. The distribution of Glucose and SkinThickness for both outcomes is left-skewed, concentrated between 5 and 50 SkinThickness, and peaked at 200 glucose. Similarly, the distribution of Glucose and DiabetesPedigreeFunction for both outcomes is left-skewed and concentrated between 0 and 1 DiabetesPedigreeFunction.
#
#   The pairplot of SkinThickness and Glucose for outcome 0 is left-skewed, concentrated between 75 and 125 glucose, and peaked at 60 SkinThickness. On the other hand, for outcome 1, it is right-skewed, concentrated between 125 and 200 glucose with a peak of 100 SkinThickness. The distribution of SkinThickness and SkinThickness for both outcomes is left-skewed, concentrated between 5 and 50 SkinThickness with a peak of 100 SkinThickness for outcome 0 and 40 SkinThickness for outcome 1. The distribution of SkinThickness and DiabetesPedigreeFunction for both outcomes is left-skewed, concentrated between 0 and 1 DiabetesPedigreeFunction with a peak of 60 SkinThickness for outcome 0 and 100 SkinThickness for outcome 1.
#
#   Lastly, for DiabetesPedigreeFunction and Glucose, the distribution for outcome 0 is left-skewed, concentrated between 75 and 125 glucose, with a peak of 2.35 DiabetesPedigreeFunction. For outcome 1, the distribution is right-skewed, concentrated between 150 and 200 glucose, with a peak of 2.5 DiabetesPedigreeFunction. The distribution of DiabetesPedigreeFunction and SkinThickness for both outcomes is left-skewed, concentrated between 12.5 and 50 SkinThickness with a peak of 2.35 DiabetesPedigreeFunction for outcome 0 and 2.5 DiabetesPedigreeFunction for outcome 1. Lastly, the distribution of DiabetesPedigreeFunction and DiabetesPedigreeFunction for both outcomes is left-skewed, concentrated between 0 and 1 DiabetesPedigreeFunction with a peak of 2.5 DiabetesPedigreeFunction for outcome 0 and 1 DiabetesPedigreeFunction for outcome 1.

# %% [markdown]
# ## Q16. Plot the scatterplot between 'Glucose' and 'Insulin'. Write your observations from the plot. (2 Marks)

# %%
sns.scatterplot(x='Glucose',y='Insulin',data=pima)
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 16:
#   Most of the population seems to have insulin about 100, but there is one that is past the 800 mark, but the densets part seems to be between 80 to 160 glucose.

# %% [markdown]
# ## Q 17. Plot the boxplot for the 'Age' variable. Are there outliers? (2 Marks)

# %%
plt.boxplot(pima['Age'])

plt.title('Boxplot of Age')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 17:
#   yes, there are outliers.

# %% [markdown]
# ## Q18. Plot histograms for the 'Age' variable to understand the number of women in different age groups given whether they have diabetes or not. Explain both histograms and compare them. (3 Marks)

# %%
plt.hist(pima[pima['Outcome']==1]['Age'], bins = 5)
plt.title('Distribution of Age for Women who has Diabetes')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(pima[pima['Outcome']==0]['Age'], bins = 5)
plt.title('Distribution of Age for Women who do not have Diabetes')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 18:
#   The first histogram shows the ages of individuals with diabetes, and the second histogram shows the ages of individuals without diabetes. First there are more individuals without diabetes in the dataset than individuals with diabetes. Comparing the two tables, it appears that individuals with diabetes tend to be older than those without diabetes. The ages in the first histogram range from 21 to 66, with a mean age of about 37, while the ages in the second histogram range from 21 to 81, with a mean age of about 31.

# %% [markdown]
# ## Q 19. What is the Interquartile Range of all the variables? Why is this used? Which plot visualizes the same? (2 Marks)

# %%
Q1 = pima.quantile(0.25)
Q3 = pima.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Pregnancies                  5.0000
# Glucose                     40.5000
# BloodPressure               16.0000
# SkinThickness               12.0000
# Insulin                     48.2500
# BMI                          9.1000
# DiabetesPedigreeFunction     0.3825
# Age                         17.0000
# Outcome                      1.0000
# dtype: float64

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 19:
# The Interquartile Range of all the variables are:
# variables                   Values
# -----------------------------------
# Pregnancies                  5.0000
# Glucose                     40.5000
# BloodPressure               16.0000
# SkinThickness               12.0000
# Insulin                     48.2500
# BMI                          9.1000
# DiabetesPedigreeFunction     0.3825
# Age                         17.0000
# Outcome                      1.0000
# -----------------------------------
# The Interquartile Range is used to measure the spread of the middle half of your data.
# The plot that visualizes the Interquartile Range the best is the box plot.

# %% [markdown]
# ## Q 20. Find and visualize the correlation matrix. Write your observations from the plot. (3 Marks)

# %%
corr_matrix = pima.iloc[:,0:8].corr()

corr_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.128022       0.208987       0.009393
# Glucose                      0.128022  1.000000       0.219765       0.158060
# BloodPressure                0.208987  0.219765       1.000000       0.130403
# SkinThickness                0.009393  0.158060       0.130403       1.000000
# Insulin                     -0.018780  0.396137       0.010492       0.245410
# BMI                          0.021546  0.231464       0.281222       0.532552
# DiabetesPedigreeFunction    -0.033523  0.137158       0.000471       0.157196
# Age                          0.544341  0.266673       0.326791       0.020582
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.018780  0.021546                 -0.033523
# Glucose                   0.396137  0.231464                  0.137158
# ...

# %%
plt.figure(figsize=(8,8))
sns.heatmap(corr_matrix, annot = True)

# display the plot
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 20:
#   The correlation matrix shows the correlation coefficients between the variables in the pima dataset. Some variables have stronger correlations with each other than others. For example, 'Pregnancies' has a strong positive correlation with 'Age', 'Glucose' has a strong positive correlation with 'Insulin', and 'BMI' has a strong positive correlation with 'SkinThickness'. Some variables also have weak negative or positive correlations with each other. Overall, the correlation coefficients suggest that 'Glucose', 'BMI', 'Insulin', and 'Age' have relatively strong positive correlations with 'Outcome', indicating that they may be important predictors of diabetes.
